# %% [markdown]
# <h1><center>Práctica Aprendizaje: Airbnb.</center></h1>

# %% [markdown]
# <h1><center>Análisis Exploratorio de los datos</center></h1>

# %% [markdown]
# # Introducción

# %% [markdown]
# - Conjunto de datos: El conjunto de datos escogido es éste, extraído de Airbnb mediante técnicas de scraping. Dentro de las opciones recomiendo utilizar el extract (“Only the 14780 selected records”), ya que minimiza el tiempo de ejecución y evita problemas de memoria en equipos con menos prestaciones. airbnb-listing-extract.csv
# - Se busca crear un evaluador automático de precios a partir de las carácterísticas de los alojamientos.

# %% [markdown]
# # 0. Librerías

# %%
# Paquetes y librerias
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt  

# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Análisis exploratorio de los datos

# %% [markdown]
# ## 1.1 Selección de variables

# %% [markdown]
# Vamos a comenzar con una exploración previa de los datos por si fuera necesario realizar cambios o transformaciones en los mismos.

# %% [markdown]
# En primer lugar, cargamos los datos y miramos la dimensión y la estructura.

# %%
# Cargamos los datos
df = pd.read_csv("airbnb-listings-cleaned.csv")
df_original = df.copy()

df.head(5)
# Out:
#       id experiences_offered  host_id    host_name  host_since  \
# 0  10080                none    30899         Rami  2009-08-10
# 1  11400                none    42305       Jaynne  2009-09-30
# 2  13188                none    51466  Family Guns  2009-11-04
# 3  13357                none    52118      Liliana  2009-11-07
# 4  13358                none    52116         Lynn  2009-11-07
#
#                          host_location  host_response_time host_response_rate  \
# 0  Vancouver, British Columbia, Canada  within a few hours                85%
# 1  Vancouver, British Columbia, Canada                 NaN                NaN
# 2  Vancouver, British Columbia, Canada      within an hour               100%
# 3  Vancouver, British Columbia, Canada      within an hour               100%
# 4  Vancouver, British Columbia, Canada                 NaN                NaN
#
#    host_acceptance_rate host_is_superhost  ... instant_bookable  \
# 0                   NaN                 f  ...                f
# 1                   NaN                 f  ...                f
# 2                   NaN                 t  ...                t
# 3                   NaN                 f  ...                f
# 4                   NaN                 f  ...                f
#
#    is_business_travel_ready          cancellation_policy  \
# 0                         f  strict_14_with_grace_period
# 1                         f  strict_14_with_grace_period
# 2                         f                     moderate
# 3                         f  strict_14_with_grace_period
# 4                         f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             t                                t
# 2                             f                                f
# 3                             t                                t
# 4                             f                                t
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                             31                                          31
# 1                              1                                           0
# 2                              1                                           1
# 3                              2                                           2
# 4                              1                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            1
# 2                                            0
# 3                                            0
# 4                                            0
#
#    calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                            0              0.18
# 1                                            0              0.64
# 2                                            0              1.51
# 3                                            0              0.51
# 4                                            0              3.65
#
# [5 rows x 82 columns]

# %%
# Dimension de los datos
df.shape
# Out:
# (4837, 82)

# %% [markdown]
# Tenemos 4837 registros de 82 variables.
#
# Estas se explican en el README.

# %% [markdown]
# Vemos el tipo de las variables y si existen valores nulos.

# %%
# Tipo de las variables y valores nulos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4837 entries, 0 to 4836
# Data columns (total 82 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            4837 non-null   int64
#  1   experiences_offered                           4837 non-null   object
#  2   host_id                                       4837 non-null   int64
#  3   host_name                                     4836 non-null   object
#  4   host_since                                    4836 non-null   object
#  5   host_location                                 4830 non-null   object
#  6   host_response_time                            2731 non-null   object
#  7   host_response_rate                            2731 non-null   object
#  8   host_acceptance_rate                          0 non-null      float64
#  9   host_is_superhost                             4836 non-null   object
#  10  host_neighbourhood                            4252 non-null   object
#  11  host_listings_count                           4836 non-null   float64
#  12  host_total_listings_count                     4836 non-null   float64
#  13  host_has_profile_pic                          4836 non-null   object
#  14  host_identity_verified                        4836 non-null   object
#  15  street                                        4837 non-null   object
#  16  neighbourhood                                 4551 non-null   object
#  17  neighbourhood_cleansed                        4837 non-null   object
#  18  neighbourhood_group_cleansed                  0 non-null      float64
#  19  city                                          4832 non-null   object
#  20  state                                         4826 non-null   object
#  21  zipcode                                       4730 non-null   object
#  22  market                                        4831 non-null   object
#  23  smart_location                                4837 non-null   object
#  24  country_code                                  4837 non-null   object
#  25  country                                       4837 non-null   object
#  26  latitude                                      4837 non-null   float64
#  27  longitude                                     4837 non-null   float64
#  28  is_location_exact                             4837 non-null   object
#  29  property_type                                 4837 non-null   object
#  30  room_type                                     4837 non-null   object
#  31  accommodates                                  4837 non-null   int64
#  32  bathrooms                                     4837 non-null   float64
#  33  bedrooms                                      4835 non-null   float64
#  34  beds                                          4831 non-null   float64
#  35  bed_type                                      4837 non-null   object
#  36  square_feet                                   78 non-null     float64
#  37  price                                         4837 non-null   float64
#  38  weekly_price                                  557 non-null    float64
#  39  monthly_price                                 592 non-null    float64
#  40  security_deposit                              4052 non-null   float64
#  41  cleaning_fee                                  4423 non-null   float64
#  42  guests_included                               4837 non-null   int64
#  43  extra_people                                  4837 non-null   object
#  44  minimum_nights                                4837 non-null   int64
#  45  maximum_nights                                4837 non-null   int64
#  46  minimum_minimum_nights                        4837 non-null   int64
#  47  maximum_minimum_nights                        4837 non-null   int64
#  48  minimum_maximum_nights                        4837 non-null   int64
#  49  maximum_maximum_nights                        4837 non-null   int64
#  50  minimum_nights_avg_ntm                        4837 non-null   float64
#  51  maximum_nights_avg_ntm                        4837 non-null   float64
#  52  calendar_updated                              4837 non-null   object
#  53  has_availability                              4837 non-null   object
#  54  availability_30                               4837 non-null   int64
#  55  availability_60                               4837 non-null   int64
#  56  availability_90                               4837 non-null   int64
#  57  availability_365                              4837 non-null   int64
#  58  calendar_last_scraped                         4837 non-null   object
#  59  number_of_reviews                             4837 non-null   int64
#  60  number_of_reviews_ltm                         4837 non-null   int64
#  61  first_review                                  4155 non-null   object
#  62  last_review                                   4155 non-null   object
#  63  review_scores_rating                          4132 non-null   float64
#  64  review_scores_accuracy                        4131 non-null   float64
#  65  review_scores_cleanliness                     4132 non-null   float64
#  66  review_scores_checkin                         4129 non-null   float64
#  67  review_scores_communication                   4130 non-null   float64
#  68  review_scores_location                        4129 non-null   float64
#  69  review_scores_value                           4129 non-null   float64
#  70  requires_license                              4837 non-null   object
#  71  license                                       3770 non-null   object
#  72  instant_bookable                              4837 non-null   object
#  73  is_business_travel_ready                      4837 non-null   object
#  74  cancellation_policy                           4837 non-null   object
#  75  require_guest_profile_picture                 4837 non-null   object
#  76  require_guest_phone_verification              4837 non-null   object
#  77  calculated_host_listings_count                4837 non-null   int64
#  78  calculated_host_listings_count_entire_homes   4837 non-null   int64
#  79  calculated_host_listings_count_private_rooms  4837 non-null   int64
#  80  calculated_host_listings_count_shared_rooms   4837 non-null   int64
#  81  reviews_per_month                             4155 non-null   float64
# dtypes: float64(25), int64(20), object(37)
# memory usage: 3.0+ MB

# %% [markdown]
# **Variables**

# %% [markdown]
# Consideramos para el estudio cualitativo del host todas las variables referidas al mismo
#
# - host_id
# - host_name
# - host_since
# - host_location
# - host_response_time
# - host_response_rate
# - host_is_superhost
# - host_neighbourhood
# - host_listings_count
# - host_total_listings_count
# - host_has_profile_pic
# - host_identity_verified
#
# Selección de variables para el modelo:
#
# - latitude
# - longitude
# - room_type
# - accommodates
# - bathrooms
# - bedrooms
# - beds
# - price
# - security_deposit
# - cleaning_fee
# - guests_inclueded
# - extra_people
# - minimum_nights
# - maximum_nights
# - number_of_reviews
# - review_scores_accuracy
# - review_scores_cleanliness
# - review_scores_checkin
# - review_scores_communication
# - review_scores_location

# %% [markdown]
# En primer lugar, creamos el dataframe para el estudio exploratorio del host

# %%
# Creamos un dataframe para el estudio cualitativo del host
col_host = [0,2,3,4,5,6,7,9,10,11,12,13,14]
df_host = df.iloc[:,col_host]

df_host = df_host.set_index('id')
df_host.head(1)
# Out:
#        host_id host_name  host_since                        host_location  \
# id
# 10080    30899      Rami  2009-08-10  Vancouver, British Columbia, Canada
#
#        host_response_time host_response_rate host_is_superhost  \
# id
# 10080  within a few hours                85%                 f
#
#       host_neighbourhood  host_listings_count  host_total_listings_count  \
# id
# 10080       Coal Harbour                 31.0                       31.0
#
#       host_has_profile_pic host_identity_verified
# id
# 10080                    t                      t

# %% [markdown]
# Por otro lado, creamos el dataframe para la tasación

# %%
# Dataframe para el estudio
col_tasa = [0,26,27,30,31,32,33,34,37,40,41,42,43,44,45,59,64,65,66,67,68]
df = df.iloc[:,col_tasa]

# %%
# Comprobamos que el indice es valido
df['id'].isnull().sum()
df['id'].duplicated().sum()

# Cambiamos el indice
df = df.set_index('id')
df_original = df_original.set_index('id')

df.head(1)
# Out:
#         latitude   longitude        room_type  accommodates  bathrooms  \
# id
# 10080  49.287716 -123.121103  Entire home/apt             6        2.0
#
#        bedrooms  beds  price  security_deposit  cleaning_fee  guests_included  \
# id
# 10080       2.0   4.0  295.0               0.0         195.0                1
#
#       extra_people  minimum_nights  maximum_nights  number_of_reviews  \
# id
# 10080       $0.00               60            1124                 16
#
#        review_scores_accuracy  review_scores_cleanliness  \
# id
# 10080                     9.0                        9.0
#
#        review_scores_checkin  review_scores_communication  \
# id
# 10080                   10.0                          9.0
#
#        review_scores_location
# id
# 10080                    10.0

# %% [markdown]
# ## 1.2 Transformación de variables

# %% [markdown]
# Realizamos algunas transformaciones sobre las varibles

# %% [markdown]
# ### 1.2.1 Tranformaciones en el dataframe del host

# %%
# Nos quedamos solo con el año de host_since 
df_host['host_since'] = pd.to_datetime(df_host['host_since'], errors='coerce')
df_host['host_since'] = df_host['host_since'].dt.year
df_host['host_since'] = 2019 - df_host['host_since'].values
df_host = df_host.rename(columns={'host_since': 'host_for'})

# %%
# Cambiamos variables dicotomicas a binario 1:t y 0:f
df_host['host_is_superhost'] = df_host['host_is_superhost'].map({"t":1, "f":0})
df_host['host_has_profile_pic'] = df_host['host_has_profile_pic'].map({"t":1, "f":0})
df_host['host_identity_verified'] = df_host['host_identity_verified'].map({"t":1, "f":0})

# %%
# Cambiamos host_response_time a tasa
df_host['host_response_rate'] = df_host['host_response_rate'].str.replace('%','').astype('float64')
df_host['host_response_rate'] = df_host['host_response_rate']/100

# %%
df_host.head(2)
# Out:
#        host_id host_name  host_for                        host_location  \
# id
# 10080    30899      Rami      10.0  Vancouver, British Columbia, Canada
# 11400    42305    Jaynne      10.0  Vancouver, British Columbia, Canada
#
#        host_response_time  host_response_rate  host_is_superhost  \
# id
# 10080  within a few hours                0.85                0.0
# 11400                 NaN                 NaN                0.0
#
#       host_neighbourhood  host_listings_count  host_total_listings_count  \
# id
# 10080       Coal Harbour                 31.0                       31.0
# 11400         Riley Park                  1.0                        1.0
#
#        host_has_profile_pic  host_identity_verified
# id
# 10080                   1.0                     1.0
# 11400                   1.0                     1.0

# %% [markdown]
# ### 1.2.2 Transformaciones en el dataframe de estudio

# %% [markdown]
# Continuamos con el dataframe de estudio, df

# %%
# Cambiamos la variable room_type a dummies segun las 3 categorias
df['room_type'].value_counts()
df_rooms = pd.get_dummies(df[['room_type']], prefix = "", prefix_sep = "")
df = pd.concat([df,df_rooms], axis=1)
df.drop(['room_type'], axis = 1, inplace = True)

# %%
# Cambiamos extra_people a dtype=float64
df['extra_people'] = df['extra_people'].str.replace('$','').astype('float64')

# %%
# Comprobar que existen ofertas donde hay mas camas que gente admitida
df[df['beds']>df['accommodates']+df['guests_included']][['accommodates','beds','guests_included']]
# Out:
#           accommodates  beds  guests_included
# id
# 12391067             2   5.0                1
# 13456176             2   5.0                2
# 14202073             2   5.0                1
# 15288267             2   5.0                1
# 15508214             4   6.0                1
# 16219066             2   5.0                1
# 19589647            10  25.0                8
# 20235568             2   5.0                2
# 23340054             2   5.0                1
# 24968566             2   5.0                1
# 27504588             1   4.0                1
# 27709015             1   4.0                1
# 27834315             1   4.0                1

# %%
# Reemplazamos 'accommodates' por el numero minimo de personas necesarias para cubrir las camas
df['accommodates'] = np.where(df['beds'] > df['accommodates']+df['guests_included'], df['beds']-df['guests_included'], df['accommodates'])

# %%
# Vemos tipo de alojamiento cuando hay mas invitados que personas que pueden alojarse
indices = df[df['guests_included']>df['accommodates']].index
df_original.loc[indices,:]['property_type'].value_counts()
# Out:
# House                 20
# Condominium            7
# Serviced apartment     4
# Guest suite            4
# Apartment              4
# Loft                   2
# Townhouse              1
# Name: property_type, dtype: int64

# %% [markdown]
# En la mayoría de casos se trata de alojamientos de grandes dimensiones. Más adelante se realizará un estudio más exhaustivo.

# %% [markdown]
# ## 1.5  Análisis descriptivo

# %% [markdown]
# **Estudio cualitativo del host**

# %% [markdown]
# Podemos estudiar:
# - ¿Existen variables influyentes que determinen si un host es superhost?
# - Mapa de localización de los host

# %% [markdown]
# **Estudio de las variables para los modelos de machine learning**

# %% [markdown]
# Vemos algunos estadísticos de los datos y estudiamos la distribución de las variables.

# %%
# Estadisticos descriptivos
df.drop(columns=['latitude', 'longitude']).iloc[:,0:12].describe()
# Out:
#        accommodates    bathrooms     bedrooms         beds        price  \
# count   4837.000000  4837.000000  4835.000000  4831.000000  4837.000000
# mean       3.517056     1.320136     1.469493     1.869178   163.807732
# std        2.332824     0.667160     1.059685     1.269757   199.445018
# min        1.000000     0.000000     0.000000     0.000000    14.000000
# 25%        2.000000     1.000000     1.000000     1.000000    80.000000
# 50%        3.000000     1.000000     1.000000     1.000000   119.000000
# 75%        4.000000     1.500000     2.000000     2.000000   196.000000
# max       17.000000     8.000000    30.000000    25.000000  6500.000000
#
#        security_deposit  cleaning_fee  guests_included  extra_people  \
# count       4052.000000   4423.000000      4837.000000   4837.000000
# mean         373.262833     79.491296         1.909861     16.060161
# std          507.081634     61.085880         1.576732     26.360474
# min            0.000000      0.000000         1.000000      0.000000
# 25%          125.000000     38.000000         1.000000      0.000000
# 50%          250.000000     65.000000         1.000000     10.000000
# 75%          500.000000    100.000000         2.000000     25.000000
# max         6561.000000    500.000000        16.000000    396.000000
#
#        minimum_nights  maximum_nights  number_of_reviews
# count      4837.00000     4837.000000        4837.000000
# mean         12.60492      704.200331          33.106678
# std          31.39955     1553.291668          50.773771
# min           1.00000        1.000000           0.000000
# 25%           1.00000       60.000000           3.000000
# 50%           2.00000     1125.000000          14.000000
# 75%          30.00000     1125.000000          43.000000
# max         998.00000    99999.000000         544.000000

# %%
# Estadisticos descriptivos
df.drop(columns=['latitude', 'longitude']).iloc[:,12:].describe()
# Out:
#        review_scores_accuracy  review_scores_cleanliness  \
# count             4131.000000                4132.000000
# mean                 9.697652                   9.517667
# std                  0.682427                   0.841566
# min                  2.000000                   2.000000
# 25%                 10.000000                   9.000000
# 50%                 10.000000                  10.000000
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            4129.000000                  4130.000000
# mean                9.781061                     9.804843
# std                 0.567635                     0.578685
# min                 2.000000                     2.000000
# 25%                10.000000                    10.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  Entire home/apt  Private room  Shared room
# count             4129.000000      4837.000000   4837.000000  4837.000000
# mean                 9.665779         0.695886      0.296258     0.007856
# std                  0.611734         0.460079      0.456653     0.088295
# min                  2.000000         0.000000      0.000000     0.000000
# 25%                  9.000000         0.000000      0.000000     0.000000
# 50%                 10.000000         1.000000      0.000000     0.000000
# 75%                 10.000000         1.000000      1.000000     0.000000
# max                 10.000000         1.000000      1.000000     1.000000

# %%
# Histograma de las variables
df.drop(columns=['latitude', 'longitude']).hist(figsize=(20,15))
plt.show()

# %% [markdown]
# Podemos observar una gran asimetría por la derecha en las variables. Por tanto, tras realizar la imputación de missings y el estudio de los outliers, se estudiará el coeficiente de asimetría realizando las trasnformaciones necesarias.

# %% [markdown]
# ## 1.3 Imputación de missings

# %%
# Valores missing
df.isnull().sum()
# Out:
# latitude                         0
# longitude                        0
# accommodates                     0
# bathrooms                        0
# bedrooms                         2
# beds                             6
# price                            0
# security_deposit               785
# cleaning_fee                   414
# guests_included                  0
# extra_people                     0
# minimum_nights                   0
# maximum_nights                   0
# number_of_reviews                0
# review_scores_accuracy         706
# review_scores_cleanliness      705
# review_scores_checkin          708
# review_scores_communication    707
# review_scores_location         708
# Entire home/apt                  0
# Private room                     0
# Shared room                      0
# dtype: int64

# %% [markdown]
# ### 1.3.1 Variables 'bedrooms' y 'beds'

# %% [markdown]
# Para imputar los missing de las variables *bedrooms* y *beds* empleamos un modelo de regresión lineal donde las variables regresoras son *accommodates* y *bathrooms*.

# %%
# Librerias
from sklearn.linear_model import LinearRegression

# %% [markdown]
# En primer lugar, imputamos la variable **_bedrooms_**

# %%
# Separamos las variables
target = 'bedrooms'
regresoras = ['accommodates', 'bathrooms']

# Creamos un dataframe con las variables seleccionadas
df_imp = df[[target] + regresoras]

# Separamos los datos en dos dataframe, uno con los valores missing y otro sin valores missing
df_missing = df_imp[df_imp.isnull().any(axis=1)]
df_no_missing = df_imp.dropna()

# Ajustamos el modelo a los datos sin missing
reg = LinearRegression()
reg.fit(df_no_missing[regresoras], df_no_missing[target])

# Realizamos la imputacion de los valores missing y almacenamos los valores obtenidos en el dataframe 
pred = reg.predict(df_missing[regresoras])
df.loc[df[target].isnull(), target]= pred

# %% [markdown]
# Imputamos los missing en la variable **_beds_**

# %%
# Separamos las variables
target = 'beds'
regresoras = ['accommodates', 'bathrooms']

# Creamos un dataframe con las variables seleccionadas
df_imp = df[[target] + regresoras]

# Separamos los datos en dos dataframe, uno con los valores missing y otro sin valores missing
df_missing = df_imp[df_imp.isnull().any(axis=1)]
df_no_missing = df_imp.dropna()

# Ajustamos el modelo a los datos sin missing
reg = LinearRegression()
reg.fit(df_no_missing[regresoras], df_no_missing[target])

# Realizamos la imputacion de los valores missing y almacenamos los valores obtenidos en el dataframe 
pred = reg.predict(df_missing[regresoras])
df.loc[df[target].isnull(), target]= pred

# %% [markdown]
# ### 1.3.2 Variables 'security_deposit' y 'cleaning_fee '

# %% [markdown]
# Consideramos que los valores NaN son 0, es decir, tendrían sentido y sería que no se paga depósito ni tasas de limpieza.

# %%
df['security_deposit'] = df['security_deposit'].replace(np.nan, 0)
df['cleaning_fee'] = df['cleaning_fee'].replace(np.nan, 0)

# %% [markdown]
# ### 1.3.3 Variables tipo 'review_scores_'

# %%
review_score = ['review_scores_accuracy','review_scores_cleanliness', 'review_scores_checkin',
                  'review_scores_communication','review_scores_location']

df[df[review_score].isna().any(axis=1)][review_score]
# Out:
#           review_scores_accuracy  review_scores_cleanliness  \
# id
# 48146                        NaN                        NaN
# 1126273                      NaN                        NaN
# 1229714                      NaN                        NaN
# 1620084                      NaN                        NaN
# 1660055                      NaN                        NaN
# ...                          ...                        ...
# 32135798                     NaN                        NaN
# 32151243                     NaN                        NaN
# 32152929                     NaN                        NaN
# 32160848                     NaN                        NaN
# 32164701                     NaN                        NaN
#
#           review_scores_checkin  review_scores_communication  \
# id
# 48146                       NaN                          NaN
# 1126273                     NaN                          NaN
# 1229714                     NaN                          NaN
# 1620084                     NaN                          NaN
# 1660055                     NaN                          NaN
# ...                         ...                          ...
# 32135798                    NaN                          NaN
# 32151243                    NaN                          NaN
# 32152929                    NaN                          NaN
# 32160848                    NaN                          NaN
# 32164701                    NaN                          NaN
#
#           review_scores_location
# id
# 48146                        NaN
# 1126273                      NaN
# 1229714                      NaN
# 1620084                      NaN
# 1660055                      NaN
# ...                          ...
# 32135798                     NaN
# 32151243                     NaN
# 32152929                     NaN
# 32160848                     NaN
# 32164701                     NaN
#
# [708 rows x 5 columns]

# %% [markdown]
# Así, decidimos eliminar las observaciones

# %%
df = df.dropna(subset=review_score)

# %% [markdown]
# ## 1.4 Outliers

# %% [markdown]
# En primer lugar, se muestra los boxplot de cada una de las variables.

# %%
# Numero de filas y columnas necesarias para dibujar todos los boxplots
n_rows = 6
n_cols = 3
columnas = ['accommodates', 'bathrooms', 'bedrooms', 'beds', 'price', 'security_deposit', 'cleaning_fee','guests_included', 'extra_people', 'minimum_nights',
       'maximum_nights', 'number_of_reviews', 'review_scores_accuracy','review_scores_cleanliness', 'review_scores_checkin','review_scores_communication', 'review_scores_location']

# Matriz de subgraficos
fig, axs = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(10, 8))

# Boxplot de cada variable
for i, columna in enumerate(columnas):
    ax = axs[i // n_cols][i % n_cols]
    ax.boxplot(df[columna],vert=False,patch_artist=True) # boxplot de la variable
    ax.set_title(columna)

# Ajuste de espacios entre subgraficos
fig.tight_layout()

# Mostrar la figura
plt.show()

# %% [markdown]
# Estudiamos los outliers en conjunto con aquellas variables con las que podrían tener más relación. La relación entre las variables podemos estudiarla mediante la matriz de correlaciones

# %%
# Correlaciones
plt.figure(figsize=(20,10))
correlaciones= df.corr()
sns.heatmap(correlaciones,cmap="GnBu",annot=True) 
correlaciones
# Out:
#                              latitude  longitude  accommodates  bathrooms  \
# latitude                     1.000000  -0.091854     -0.068062  -0.049372
# longitude                   -0.091854   1.000000     -0.041075  -0.084609
# accommodates                -0.068062  -0.041075      1.000000   0.552023
# bathrooms                   -0.049372  -0.084609      0.552023   1.000000
# bedrooms                    -0.142906  -0.026113      0.811762   0.629066
# beds                        -0.094101  -0.026044      0.838057   0.518669
# price                        0.099694  -0.167960      0.561351   0.502955
# security_deposit             0.132790  -0.049751      0.249254   0.270065
# cleaning_fee                 0.161202  -0.126247      0.522610   0.461937
# guests_included             -0.061709  -0.014581      0.599453   0.355594
# extra_people                 0.060134  -0.023170      0.119362   0.085166
# minimum_nights               0.114318  -0.068062     -0.085348  -0.016398
# maximum_nights               0.007066  -0.014911      0.015292   0.003912
# number_of_reviews            0.079285   0.056384     -0.050108  -0.119025
# review_scores_accuracy       0.033667   0.022181     -0.070669  -0.075141
# review_scores_cleanliness    0.017332   0.037941     -0.026944  -0.052964
# review_scores_checkin       -0.050066   0.024320     -0.029805  -0.036348
# review_scores_communication  0.038948   0.016107     -0.020643  -0.031953
# review_scores_location       0.200373  -0.280161      0.041347   0.036811
# Entire home/apt              0.266724  -0.054484      0.416291   0.122795
# Private room                -0.277306   0.047656     -0.408394  -0.131523
# Shared room                  0.044477   0.037587     -0.057324   0.040499
#
#                              bedrooms      beds     price  security_deposit  \
# latitude                    -0.142906 -0.094101  0.099694          0.132790
# longitude                   -0.026113 -0.026044 -0.167960         -0.049751
# accommodates                 0.811762  0.838057  0.561351          0.249254
# bathrooms                    0.629066  0.518669  0.502955          0.270065
# bedrooms                     1.000000  0.771466  0.553984          0.246299
# beds                         0.771466  1.000000  0.508499          0.226118
# price                        0.553984  0.508499  1.000000          0.292320
# security_deposit             0.246299  0.226118  0.292320          1.000000
# cleaning_fee                 0.504547  0.476772  0.525051          0.405083
# guests_included              0.539339  0.546593  0.390711          0.194235
# extra_people                 0.104343  0.100436  0.124363          0.152284
# minimum_nights              -0.064326 -0.070786  0.004398          0.071240
# maximum_nights              -0.007094  0.004149  0.003870          0.044567
# number_of_reviews           -0.105486 -0.059888 -0.104884         -0.049730
# review_scores_accuracy      -0.056281 -0.048341  0.012297          0.004476
# review_scores_cleanliness   -0.029619 -0.015203  0.026779          0.044670
# review_scores_checkin        0.005700  0.007682 -0.015980         -0.017904
# review_scores_communication -0.001051  0.001354  0.026476         -0.007123
# review_scores_location       0.021775  0.020159  0.113195          0.047932
# Entire home/apt              0.275592  0.337740  0.351476          0.231378
# Private room                -0.269652 -0.336822 -0.345494         -0.226464
# Shared room                 -0.041650 -0.018017 -0.044847         -0.034591
#
#                              cleaning_fee  guests_included  ...  \
# latitude                         0.161202        -0.061709  ...
# longitude                       -0.126247        -0.014581  ...
# accommodates                     0.522610         0.599453  ...
# bathrooms                        0.461937         0.355594  ...
# bedrooms                         0.504547         0.539339  ...
# beds                             0.476772         0.546593  ...
# price                            0.525051         0.390711  ...
# security_deposit                 0.405083         0.194235  ...
# cleaning_fee                     1.000000         0.368321  ...
# guests_included                  0.368321         1.000000  ...
# extra_people                     0.161520         0.337433  ...
# minimum_nights                   0.079587        -0.053720  ...
# maximum_nights                   0.021604         0.008247  ...
# number_of_reviews               -0.126151         0.006298  ...
# review_scores_accuracy          -0.017357        -0.017860  ...
# review_scores_cleanliness        0.041147         0.015701  ...
# review_scores_checkin           -0.023045         0.018058  ...
# review_scores_communication      0.002189         0.015537  ...
# review_scores_location           0.104090         0.017516  ...
# Entire home/apt                  0.431257         0.269419  ...
# Private room                    -0.422422        -0.263623  ...
# Shared room                     -0.062785        -0.040658  ...
#
#                              maximum_nights  number_of_reviews  \
# latitude                           0.007066           0.079285
# longitude                         -0.014911           0.056384
# accommodates                       0.015292          -0.050108
# bathrooms                          0.003912          -0.119025
# bedrooms                          -0.007094          -0.105486
# beds                               0.004149          -0.059888
# price                              0.003870          -0.104884
# security_deposit                   0.044567          -0.049730
# cleaning_fee                       0.021604          -0.126151
# guests_included                    0.008247           0.006298
# extra_people                      -0.013568           0.005158
# minimum_nights                     0.030489          -0.064549
# maximum_nights                     1.000000          -0.022167
# number_of_reviews                 -0.022167           1.000000
# review_scores_accuracy            -0.010587           0.117334
# review_scores_cleanliness         -0.022939           0.124126
# review_scores_checkin             -0.011217           0.101267
# review_scores_communication       -0.009696           0.101632
# review_scores_location            -0.000523           0.044209
# Entire home/apt                    0.017531           0.024681
# Private room                      -0.018710          -0.019229
# Shared room                        0.005435          -0.029274
#
#                              review_scores_accuracy  \
# latitude                                   0.033667
# longitude                                  0.022181
# accommodates                              -0.070669
# bathrooms                                 -0.075141
# bedrooms                                  -0.056281
# beds                                      -0.048341
# price                                      0.012297
# security_deposit                           0.004476
# cleaning_fee                              -0.017357
# guests_included                           -0.017860
# extra_people                               0.005406
# minimum_nights                            -0.026888
# maximum_nights                            -0.010587
# number_of_reviews                          0.117334
# review_scores_accuracy                     1.000000
# review_scores_cleanliness                  0.581896
# review_scores_checkin                      0.543679
# review_scores_communication                0.613357
# review_scores_location                     0.363511
# Entire home/apt                            0.062663
# Private room                              -0.051195
# Shared room                               -0.061997
#
#                              review_scores_cleanliness  review_scores_checkin  \
# latitude                                      0.017332              -0.050066
# longitude                                     0.037941               0.024320
# accommodates                                 -0.026944              -0.029805
# bathrooms                                    -0.052964              -0.036348
# bedrooms                                     -0.029619               0.005700
# beds                                         -0.015203               0.007682
# price                                         0.026779              -0.015980
# security_deposit                              0.044670              -0.017904
# cleaning_fee                                  0.041147              -0.023045
# guests_included                               0.015701               0.018058
# extra_people                                  0.021947              -0.022554
# minimum_nights                               -0.035943              -0.003196
# maximum_nights                               -0.022939              -0.011217
# number_of_reviews                             0.124126               0.101267
# review_scores_accuracy                        0.581896               0.543679
# review_scores_cleanliness                     1.000000               0.419104
# review_scores_checkin                         0.419104               1.000000
# review_scores_communication                   0.463916               0.613173
# review_scores_location                        0.275158               0.271285
# Entire home/apt                               0.075919               0.025915
# Private room                                 -0.059077              -0.019556
# Shared room                                  -0.090414              -0.034033
#
#                              review_scores_communication  \
# latitude                                        0.038948
# longitude                                       0.016107
# accommodates                                   -0.020643
# bathrooms                                      -0.031953
# bedrooms                                       -0.001051
# beds                                            0.001354
# price                                           0.026476
# security_deposit                               -0.007123
# cleaning_fee                                    0.002189
# guests_included                                 0.015537
# extra_people                                    0.001027
# minimum_nights                                 -0.021183
# maximum_nights                                 -0.009696
# number_of_reviews                               0.101632
# review_scores_accuracy                          0.613357
# review_scores_cleanliness                       0.463916
# review_scores_checkin                           0.613173
# review_scores_communication                     1.000000
# review_scores_location                          0.361702
# Entire home/apt                                 0.078795
# Private room                                   -0.069504
# Shared room                                    -0.051322
#
#                              review_scores_location  Entire home/apt  \
# latitude                                   0.200373         0.266724
# longitude                                 -0.280161        -0.054484
# accommodates                               0.041347         0.416291
# bathrooms                                  0.036811         0.122795
# bedrooms                                   0.021775         0.275592
# beds                                       0.020159         0.337740
# price                                      0.113195         0.351476
# security_deposit                           0.047932         0.231378
# cleaning_fee                               0.104090         0.431257
# guests_included                            0.017516         0.269419
# extra_people                               0.039088         0.055554
# minimum_nights                             0.033770         0.057966
# maximum_nights                            -0.000523         0.017531
# number_of_reviews                          0.044209         0.024681
# review_scores_accuracy                     0.363511         0.062663
# review_scores_cleanliness                  0.275158         0.075919
# review_scores_checkin                      0.271285         0.025915
# review_scores_communication                0.361702         0.078795
# review_scores_location                     1.000000         0.134280
# Entire home/apt                            0.134280         1.000000
# Private room                              -0.131551        -0.981617
# Shared room                               -0.019438        -0.134665
#
#                              Private room  Shared room
# latitude                        -0.277306     0.044477
# longitude                        0.047656     0.037587
# accommodates                    -0.408394    -0.057324
# bathrooms                       -0.131523     0.040499
# bedrooms                        -0.269652    -0.041650
# beds                            -0.336822    -0.018017
# price                           -0.345494    -0.044847
# security_deposit                -0.226464    -0.034591
# cleaning_fee                    -0.422422    -0.062785
# guests_included                 -0.263623    -0.040658
# extra_people                    -0.067022     0.057359
# minimum_nights                  -0.062389     0.020689
# maximum_nights                  -0.018710     0.005435
# number_of_reviews               -0.019229    -0.029274
# review_scores_accuracy          -0.051195    -0.061997
# review_scores_cleanliness       -0.059077    -0.090414
# review_scores_checkin           -0.019556    -0.034033
# review_scores_communication     -0.069504    -0.051322
# review_scores_location          -0.131551    -0.019438
# Entire home/apt                 -0.981617    -0.134665
# Private room                     1.000000    -0.056934
# Shared room                     -0.056934     1.000000
#
# [22 rows x 22 columns]

# %% [markdown]
# Dividimos las variables en distintos grupos en función de su correlación para analizarlas conjuntamente.

# %% [markdown]
# ### 1.4.1 Variables relacionadas con la disposición del alojamiento

# %% [markdown]
# **Accommodate, bathrooms,  bedrooms, beds**

# %% [markdown]
# Primero vamos a estudiar los outliers en las variables relativas a la disposicion del alojamiento

# %%
# Boxplot de las habitaciones
fig = plt.figure(figsize = (5,5))

plt.boxplot(df[['accommodates', 'bathrooms','bedrooms', 'beds']])

plt.title('Outliers')
plt.xticks([1,2,3,4], ['Accommodates', 'Bathrooms', 'Bedrooms', 'Beds'])

plt.show()

# %% [markdown]
# Estudiamos los outliers en conjunto. Para ello empleamos la librería *PyOD* que posee estrategias para detectar outliers. En este caso, empleamos el algoritmo de KNN

# %%
# !pip install pyod

# %%
# Librerias
from pyod.models.knn import KNN

# %%
# Deteccion de outliers
A = df[['accommodates','bathrooms','bedrooms', 'beds', 'Entire home/apt', 'Private room']]
clf = KNN(contamination=0.01)
clf.fit(A)
# Outliers
y_pred = clf.predict(A)
outliers = A[y_pred == 1]
# Vemos el tipo de alojamiento
indices = outliers.index
outliers['property_type'] = df_original.loc[indices,:]['property_type']
outliers
# Out:
#           accommodates  bathrooms  bedrooms  beds  Entire home/apt  \
# id
# 1096393           10.0        1.0      10.0   1.0                1
# 6830599           16.0        3.0       4.0   7.0                1
# 15735770          14.0        3.0       5.0  10.0                1
# 15987030           1.0        8.0       1.0   1.0                0
# 16606630          13.0        1.0       3.0   3.0                1
# 16689567          10.0        3.0       5.0   9.0                1
# 17347671          14.0        2.5       3.0   7.0                1
# 17848238          10.0        2.0       2.0   2.0                1
# 19589647          17.0        3.5       5.0  25.0                1
# 20002260          12.0        2.0       2.0  12.0                1
# 20873261          16.0        4.0       5.0  11.0                1
# 23896457          16.0        4.0       7.0   7.0                1
# 25130708           7.0        2.5       7.0   6.0                1
# 27409742          16.0        1.0       3.0   7.0                1
# 27491839          14.0        1.0       4.0   5.0                1
# 27787350           8.0        1.0       1.0   2.0                0
# 27900730          16.0        8.0      10.0  10.0                1
# 28545482          16.0        6.5       6.0   6.0                1
# 28722085          16.0        6.0       8.0   8.0                1
# 28754422          10.0        4.5       4.0   8.0                1
# 29875200          12.0        4.0       7.0   7.0                1
# 29889054          14.0        4.0       7.0   9.0                1
# 30587490          10.0        7.0       5.0   5.0                1
# 31212290          16.0        7.0       5.0   8.0                1
# 31311642          16.0        6.5       9.0   9.0                1
# 31523939          16.0        2.0       6.0  13.0                1
#
#           Private room property_type
# id
# 1096393              0     Apartment
# 6830599              0         Villa
# 15735770             0         House
# 15987030             1     Apartment
# 16606630             0     Apartment
# 16689567             0         House
# 17347671             0     Townhouse
# 17848238             0         House
# 19589647             0         House
# 20002260             0   Guest suite
# 20873261             0         House
# 23896457             0         House
# 25130708             0         House
# 27409742             0   Condominium
# 27491839             0         House
# 27787350             1         House
# 27900730             0         House
# 28545482             0         Villa
# 28722085             0         House
# 28754422             0         House
# 29875200             0         House
# 29889054             0         House
# 30587490             0         House
# 31212290             0         House
# 31311642             0         House
# 31523939             0   Condominium

# %% [markdown]
# Podríamos considerar outliers los que se trata de un apartamento, dado que por lo general, el número de posibles huéspedes es muy alto y las dimensiones de un apartamento no suelen ser tan grandes.

# %%
outliers[outliers['property_type']=='Apartment']
# Out:
#           accommodates  bathrooms  bedrooms  beds  Entire home/apt  \
# id
# 1096393           10.0        1.0      10.0   1.0                1
# 15987030           1.0        8.0       1.0   1.0                0
# 16606630          13.0        1.0       3.0   3.0                1
#
#           Private room property_type
# id
# 1096393              0     Apartment
# 15987030             1     Apartment
# 16606630             0     Apartment

# %% [markdown]
# Así, podemos observar que parece que se trata de datos mal registrados.
#
# - En el primer caso, parece que se trata de un apartamente con 10 habitaciones y (posiblemente 1 cama por habitación).
# - En el segundo caso, parece que se trata de una habitación privada en un apartamento.
# - En el tercer caso
#
# Decidimos eliminar las observaciones.

# %%
# Eliminamos las observaciones correspondientes con apartamentos
indices_apt = outliers[outliers['property_type']=='Apartment'].index
df.drop(indices_apt, inplace = True)

# %% [markdown]
# ### 1.4.2 Variables relacionadas con tasas extra

# %% [markdown]
# **Security deposit, cleaning fee, guests included, extra people**

# %% [markdown]
# **Security deposit**

# %% [markdown]
# Vemos cómo se distribuye la variable y sus posibles outliers

# %%
# Distribucion y boxplot de security deposit
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.kdeplot(df['security_deposit'], shade=True, color='blue',ax=axes[0])
sns.boxplot(df['security_deposit'], color='blue', ax=axes[1])

plt.show()

# %% [markdown]
# Las fianzas altas suelen estar relacionadas con largas estancias o con lugares de grandes dimensiones. Denominamos fianza alta a aquellas por encima del cuantil 0,95.

# %%
# Dataframe con fianzas por encima del cualtil 95
q95 = df['security_deposit'].quantile(0.95) 
df_fianza = df[df['security_deposit']>=q95][['minimum_nights','maximum_nights', 
                                             'price','security_deposit','Entire home/apt', 'Private room', 'Shared room']]
indices = df_fianza.index
df_fianza['property_type'] = df_original.loc[indices]['property_type']
df_fianza
# Out:
#           minimum_nights  maximum_nights   price  security_deposit  \
# id
# 14508                 90             365   140.0            1000.0
# 26047                 30             365   159.0            1000.0
# 26234                 30             730   169.0            1000.0
# 42645                 30             730   159.0            1000.0
# 54261                 90             365    98.0            1500.0
# ...                  ...             ...     ...               ...
# 30914254               2             200    98.0            2500.0
# 31044697               2            1125   600.0            1000.0
# 31212290               2              27  1488.0            1000.0
# 31340160               1            1125    60.0            1000.0
# 31523939               1            1125  1849.0            1499.0
#
#           Entire home/apt  Private room  Shared room property_type
# id
# 14508                   1             0            0     Apartment
# 26047                   1             0            0     Apartment
# 26234                   1             0            0     Apartment
# 42645                   1             0            0   Condominium
# 54261                   1             0            0   Condominium
# ...                   ...           ...          ...           ...
# 30914254                1             0            0     Apartment
# 31044697                1             0            0     Apartment
# 31212290                1             0            0         House
# 31340160                0             1            0         House
# 31523939                1             0            0   Condominium
#
# [281 rows x 8 columns]

# %% [markdown]
# Podríamos considerar outliers aquellos que no sean larga estancia y/o no correspondan con un alojamiento de grandes dimensiones.

# %%
# Tipos de alojamiento
df_fianza['property_type'].value_counts()
# Out:
# House                 95
# Condominium           78
# Apartment             54
# Loft                  16
# Serviced apartment    11
# Townhouse             10
# Guest suite            8
# Guesthouse             3
# Villa                  3
# Other                  2
# Camper/RV              1
# Name: property_type, dtype: int64

# %%
# No son largas estancias si es menos de 6 meses? y tipo alojamiento pequeño (apartment, loft y other)?
df_fianza[(df_fianza['maximum_nights']<63) & 
          ((df_fianza['property_type']=='Apartment') | (df_fianza['property_type']=='Loft') | (df_fianza['property_type']=='Other'))]
# Out:
#           minimum_nights  maximum_nights  price  security_deposit  \
# id
# 1678196                2              60  150.0            1000.0
# 3448674                2              21  199.0            1500.0
# 7162553                7              30  196.0            1000.0
# 8868498                1              27  150.0            1000.0
# 10837935               1              30  282.0            1500.0
# 20434400               2              30   94.0            1000.0
# 24757423               2              14  300.0            2000.0
# 25414923               1              24  150.0            1000.0
#
#           Entire home/apt  Private room  Shared room property_type
# id
# 1678196                 1             0            0     Apartment
# 3448674                 1             0            0          Loft
# 7162553                 1             0            0          Loft
# 8868498                 1             0            0         Other
# 10837935                1             0            0          Loft
# 20434400                0             1            0     Apartment
# 24757423                1             0            0     Apartment
# 25414923                1             0            0     Apartment

# %%
# Eliminamos las observaciones que no son largas estancias o grandes alojamientos
indices_est = df_fianza[(df_fianza['maximum_nights']<63) & 
                        ((df_fianza['property_type']=='Apartment') | (df_fianza['property_type']=='Loft') | (df_fianza['property_type']=='Other'))].index
df.drop(indices_est, inplace = True)

# %% [markdown]
# **Cleaning fee**

# %% [markdown]
# Vemos la distribución de _cleaning_fee_ y sus posibles valores atípicos

# %%
# Distribucion y boxplot de cleaning fee
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.kdeplot(df['cleaning_fee'], shade=True, color='blue',ax=axes[0])
sns.boxplot(df['cleaning_fee'], color='blue', ax=axes[1])

plt.show()

# %% [markdown]
# Estudiamos la relación entre 'cleaning_fee' y 'review_scores_cleanliness'.

# %%
# Relacion cleanin_fee y review_score_cleanliness
plt.scatter(df['cleaning_fee'],df['review_scores_cleanliness'])
plt.plot( [0, 500],  [0, 10] , color='red')
plt.xlabel('Cleaning Fee')
plt.ylabel('Review Scores Cleanliness')
# Out:
# Text(0, 0.5, 'Review Scores Cleanliness')

# %% [markdown]
# Consideramos que todos los datos que estén por debajo de la línea son outliers. Decidimos eliminarlos.

# %%
# Eliminamos las observaciones
indices = df[(df['cleaning_fee']>100)&(df['review_scores_cleanliness']<3)].index
df.drop(indices, inplace=True)

# %% [markdown]
# Representamos las tasas de limpieza para los distintos tipos de alojamiento.

# %%
# Crear la figura y los ejes
fig, axs = plt.subplots()

# Tramar el gráfico de dispersión con diferentes categorías
axs.scatter(df[df['Entire home/apt'] == 1]['cleaning_fee'], [1] * len(df[df['Entire home/apt'] == 1]), label='Entire home/apt')
axs.scatter(df[df['Private room'] == 1]['cleaning_fee'], [2] * len(df[df['Private room'] == 1]), label='Private room')
axs.scatter(df[df['Shared room'] == 1]['cleaning_fee'], [3] * len(df[df['Shared room'] == 1]), label='Shared room')

# Añadir etiquetas a los ejes
axs.set_xlabel('Cleaning Fee')
axs.set_yticks([1, 2, 3])
axs.set_yticklabels(['Entire home/apt', 'Private room', 'Shared room'])

# Mostrar la leyenda
axs.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Guests included**

# %% [markdown]
# Podemos estudiar esta variable en conjunto de con número de huéspedes y el número de camas/habitaciones

# %%
# Distribucion y boxplot de guests_included
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.histplot(df['guests_included'], bins=30, alpha=0.5, color='blue', ax=axes[0])
sns.boxplot(df['guests_included'], color='blue', ax=axes[1])

plt.show()

# %%
df['guests_included'].value_counts() # Para ver valores atipicos de guests_included
# Out:
# 1     2282
# 2     1057
# 4      421
# 3      120
# 6      114
# 5       55
# 8       23
# 7       13
# 10      10
# 12       9
# 11       4
# 16       3
# 9        3
# 15       1
# 14       1
# Name: guests_included, dtype: int64

# %%
# Dataframe con posibles valores atipicos de guests_included
outliers_guests = df[df['guests_included']>8][['accommodates', 'bathrooms', 'bedrooms', 'beds', 'price',
                                               'guests_included', 'Entire home/apt', 'Private room']] # Para ver en conjunto
outliers_guests
# Out:
#           accommodates  bathrooms  bedrooms  beds   price  guests_included  \
# id
# 1032892            2.0        1.0       1.0   1.0    94.0               15
# 5698137            5.0        2.0       3.0   3.0   600.0               10
# 6830599           16.0        3.0       4.0   7.0   201.0               16
# 9811578           15.0        3.5       5.0   7.0   256.0               11
# 14090993           8.0        5.0       5.0   6.0   295.0               12
# 15646460          10.0        3.0       4.0   8.0   500.0               10
# 15735770          14.0        3.0       5.0  10.0   300.0               10
# 16339748          11.0        3.0       4.0   6.0   600.0               11
# 16689567          10.0        3.0       5.0   9.0   500.0               12
# 20281112          12.0        3.0       5.0   6.0   655.0               10
# 21783156          14.0        2.0       5.0   7.0   627.0               12
# 21968371           2.0        1.0       1.0   1.0    39.0               10
# 23576992          10.0        6.0       5.0   5.0   680.0               10
# 23810907           2.0        1.0       1.0   1.0    98.0               10
# 24632717          11.0        2.0       6.0   6.0   500.0               11
# 25431016          11.0        2.0       4.0   6.0   450.0               11
# 25519615           9.0        5.0       4.0   5.0   600.0                9
# 25539435           9.0        3.5       3.0   1.0   899.0                9
# 27395451          16.0        4.0       6.0   8.0   699.0               12
# 27491839          14.0        1.0       4.0   5.0   279.0               10
# 27585804          14.0        3.5       6.0   7.0   650.0               12
# 27900730          16.0        8.0      10.0  10.0  1250.0               16
# 28563877          10.0        4.0       5.0   5.0   299.0               10
# 29649427          12.0        3.5       5.0   6.0   475.0               12
# 29996035          16.0        3.0       6.0   6.0   449.0               12
# 30178554          10.0        2.5       6.0   6.0   600.0               10
# 30743268          12.0        2.0       6.0   7.0   600.0               12
# 30857570           9.0        2.0       4.0   4.0   400.0                9
# 31212290          16.0        7.0       5.0   8.0  1488.0               16
# 31311642          16.0        6.5       9.0   9.0   699.0               14
# 31523939          16.0        2.0       6.0  13.0  1849.0               12
#
#           Entire home/apt  Private room
# id
# 1032892                 0             1
# 5698137                 1             0
# 6830599                 1             0
# 9811578                 1             0
# 14090993                1             0
# 15646460                1             0
# 15735770                1             0
# 16339748                1             0
# 16689567                1             0
# 20281112                1             0
# 21783156                1             0
# 21968371                0             1
# 23576992                1             0
# 23810907                0             1
# 24632717                1             0
# 25431016                1             0
# 25519615                1             0
# 25539435                1             0
# 27395451                1             0
# 27491839                1             0
# 27585804                1             0
# 27900730                1             0
# 28563877                1             0
# 29649427                1             0
# 29996035                1             0
# 30178554                1             0
# 30743268                1             0
# 30857570                1             0
# 31212290                1             0
# 31311642                1             0
# 31523939                1             0

# %% [markdown]
# Podemos considerar outliers aquellos donde 'accommodates' < 'guests_included'

# %%
# Outliers
outliers_guests[outliers_guests['accommodates']<outliers_guests['guests_included']]
# Out:
#           accommodates  bathrooms  bedrooms  beds  price  guests_included  \
# id
# 1032892            2.0        1.0       1.0   1.0   94.0               15
# 5698137            5.0        2.0       3.0   3.0  600.0               10
# 14090993           8.0        5.0       5.0   6.0  295.0               12
# 16689567          10.0        3.0       5.0   9.0  500.0               12
# 21968371           2.0        1.0       1.0   1.0   39.0               10
# 23810907           2.0        1.0       1.0   1.0   98.0               10
#
#           Entire home/apt  Private room
# id
# 1032892                 0             1
# 5698137                 1             0
# 14090993                1             0
# 16689567                1             0
# 21968371                0             1
# 23810907                0             1

# %%
# Eliminamos las observaciones
df.drop(outliers_guests[outliers_guests['accommodates']<outliers_guests['guests_included']].index, inplace=True)

# %% [markdown]
# **Extra people**

# %% [markdown]
# Podemos estudiar esta variable en conjunto con el tipo de alojamiento y 'guests_included'. En primer lugar, observamos su distribución y los posibles valores atípicos.

# %%
# Distribucion y boxplot de extra_people
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.kdeplot(df['extra_people'], shade=True, color='blue',ax=axes[0])
sns.boxplot(df['extra_people'], color='blue', ax=axes[1])

plt.show()

# %% [markdown]
# Consideramos posibles outliers aquellos por encima del cuantil 0,95 (ó del cuantil 0,99)

# %%
# Dataframe con posibles outliers extra_people
q99 = df['extra_people'].quantile(0.99)
outliers_extra = df[df['extra_people']>q99][['accommodates', 'bathrooms', 'bedrooms', 'beds', 'price', 'guests_included', 'extra_people', 
                            'Entire home/apt', 'Private room', 'Shared room']]
outliers_extra
# Out:
#           accommodates  bathrooms  bedrooms  beds  price  guests_included  \
# id
# 2460888            2.0        1.0       1.0   1.0  197.0                2
# 2675179            4.0        2.0       2.0   2.0  450.0                4
# 2703279            6.0        2.0       3.0   4.0  500.0                6
# 5538655            4.0        1.0       2.0   2.0   81.0                4
# 6249125            4.0        1.0       1.0   2.0  249.0                2
# 12603779           2.0        1.0       1.0   1.0  100.0                2
# 13291492           2.0        1.0       1.0   1.0  199.0                2
# 13620049           3.0        2.0       2.0   2.0  350.0                3
# 14074129           2.0        1.0       1.0   2.0   98.0                2
# 18079483           2.0        1.0       1.0   1.0  230.0                2
# 20192706           2.0        1.0       1.0   1.0  151.0                2
# 20234976           1.0        2.0       2.0   1.0  157.0                1
# 20261505           4.0        1.0       2.0   2.0  251.0                4
# 20413544           5.0        3.0       2.0   2.0  409.0                4
# 20744422           2.0        1.0       1.0   1.0   98.0                2
# 20900425           6.0        2.5       3.0   3.0  199.0                6
# 22292913           2.0        1.0       1.0   1.0  150.0                1
# 22684147           8.0        2.5       4.0   4.0  398.0                8
# 23064387           4.0        2.0       2.0   2.0  251.0                4
# 23576992          10.0        6.0       5.0   5.0  680.0               10
# 25351552           4.0        2.0       2.0   2.0  399.0                4
# 25539435           9.0        3.5       3.0   1.0  899.0                9
# 25875124           5.0        2.0       2.0   2.0  650.0                5
# 27343609           1.0        1.0       1.0   2.0  139.0                1
# 28604839           3.0        1.0       1.0   2.0  146.0                2
# 28658718           4.0        1.0       2.0   2.0  300.0                4
#
#           extra_people  Entire home/apt  Private room  Shared room
# id
# 2460888          328.0                1             0            0
# 2675179          350.0                1             0            0
# 2703279          395.0                1             0            0
# 5538655          200.0                1             0            0
# 6249125          191.0                1             0            0
# 12603779         395.0                1             0            0
# 13291492         199.0                1             0            0
# 13620049         250.0                1             0            0
# 14074129         118.0                1             0            0
# 18079483         350.0                1             0            0
# 20192706         210.0                1             0            0
# 20234976         130.0                0             1            0
# 20261505         150.0                1             0            0
# 20413544         150.0                1             0            0
# 20744422         200.0                1             0            0
# 20900425         395.0                1             0            0
# 22292913         200.0                1             0            0
# 22684147         150.0                1             0            0
# 23064387         396.0                1             0            0
# 23576992         150.0                1             0            0
# 25351552         125.0                1             0            0
# 25539435         150.0                1             0            0
# 25875124         200.0                1             0            0
# 27343609         139.0                0             1            0
# 28604839         300.0                1             0            0
# 28658718         200.0                1             0            0

# %% [markdown]
# Una primera aproximación sería tomar como valores atípicos aquellos en los que la variable 'extra_people' es mayor que el precio por persona y contabilizamos los invitados.

# %%
# Outliers
outliers_extra[outliers_extra['extra_people']>outliers_extra['price']*outliers_extra['guests_included']]
# Out:
#           accommodates  bathrooms  bedrooms  beds  price  guests_included  \
# id
# 12603779           2.0        1.0       1.0   1.0  100.0                2
# 20744422           2.0        1.0       1.0   1.0   98.0                2
# 22292913           2.0        1.0       1.0   1.0  150.0                1
# 28604839           3.0        1.0       1.0   2.0  146.0                2
#
#           extra_people  Entire home/apt  Private room  Shared room
# id
# 12603779         395.0                1             0            0
# 20744422         200.0                1             0            0
# 22292913         200.0                1             0            0
# 28604839         300.0                1             0            0

# %% [markdown]
# Eliminamos esas observaciones

# %%
# Eliminamos las observaciones
df.drop(outliers_extra[outliers_extra['extra_people']>outliers_extra['price']*outliers_extra['guests_included']].index, inplace =True)

# %% [markdown]
# ### 1.4.3 Variables relacionadas las reseñas

# %% [markdown]
# Las reseñas son muy subjetivas y pueden presentar mucha variabilidad. Por ejemplo, puede darse el caso de un alojamiento situao en una muy buena ubicación pero con pésimas condiciones de limpieza.

# %% [markdown]
# **review_score_bla**

# %% [markdown]
# Calculamos la puntuación media según el tipo de habitación

# %%
reviews = df[['number_of_reviews','review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 
              'review_scores_communication', 'review_scores_location']]

indices_reviews = reviews.index
reviews['room_type'] = df_original.loc[indices_reviews,:]['room_type']

# Valoraciones media segun el tipo de habitaciom    
df_media = reviews.groupby(['room_type']).mean()
df_media
# Out:
#                  number_of_reviews  review_scores_accuracy  \
# room_type
# Entire home/apt          39.639470                9.730474
# Private room             37.287728                9.644279
# Shared room              21.250000                9.218750
#
#                  review_scores_cleanliness  review_scores_checkin  \
# room_type
# Entire home/apt                   9.563808               9.793236
# Private room                      9.440299               9.763682
# Shared room                       8.656250               9.562500
#
#                  review_scores_communication  review_scores_location
# room_type
# Entire home/apt                     9.837866                9.718968
# Private room                        9.742123                9.544776
# Shared room                         9.468750                9.531250

# %% [markdown]
# **Otra idea**: Intentar mirar reviews por zonas con latitude y longitude

# %% [markdown]
# ### 1.4.4 Variables relacionadas con las noches

# %% [markdown]
# **minimum**

# %% [markdown]
# En primer lugar, sacamos los estadísticos de esta variable

# %%
# Estadisticos descriptivos
df['minimum_nights'].describe()
# Out:
# count    4106.000000
# mean       10.772528
# std        29.114849
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         7.000000
# max       998.000000
# Name: minimum_nights, dtype: float64

# %% [markdown]
# Así, podemos observar que mientras existen algunos casos con un número de noches muy superior al número de noches hasta el 75% de los datos

# %%
# Estancias minimas de mas de medio año 
df[df['minimum_nights']>180][['minimum_nights','maximum_nights']]
# Out:
#           minimum_nights  maximum_nights
# id
# 11400                364             364
# 5958136              365            1125
# 11102652             365             365
# 13771205             998             999
# 15819364             900             901

# %% [markdown]
# También podemos ver que existen algunos casos extraños donde la duración de la estancia es muy particular

# %%
# Intervalos de un dia entre min y max
df[df['maximum_nights']-df['minimum_nights']<2][['minimum_nights', 'maximum_nights']]
# Out:
#           minimum_nights  maximum_nights
# id
# 11400                364             364
# 13357                 30              30
# 1191143                3               3
# 7787575               98              99
# 11102652             365             365
# 11949456               2               3
# 12434489               1               1
# 13771205             998             999
# 13817015              30              30
# 15314563              30              31
# 15448228              30              31
# 15819364             900             901
# 15840160               1               2
# 16631353              30              30
# 17438123               3               3
# 17546167              31              31
# 18287761              60              60
# 18638835               1               2
# 18894921              30              30
# 19073601              30              30
# 19101912               3               4
# 22424497              30              30
# 23546333              30              30
# 23595946              60              60
# 25011581               2               2
# 25750741               5               6
# 25887824              21              21
# 26424386               1               2
# 28765752               1               1

# %% [markdown]
# Decidimos borrar estos últimos

# %%
# Eliminamos las observaciones
df.drop(df[df['maximum_nights']-df['minimum_nights']<2][['minimum_nights', 'maximum_nights']].index, inplace = True)

# %% [markdown]
# Procedemos a estudiar el resto de los casos.
#
# Observamos la distribución del número mínimo de noches

# %%
# Distribucion de minimum_nights
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.kdeplot(df['minimum_nights'], shade=True, color='blue', ax=axes[0])
sns.histplot(df['minimum_nights'], color='blue', bins = 30, ax=axes[1])

plt.show()

# %% [markdown]
# Hay dos picos, uno para alquileres por noche (min 1 noche) y otro para alquieres por meses (min 30 noche).
#
# **Nota de Sofía**: No entiendo .
# En este caso, sí que parecetner sentido poder hacer el corte por arriba????

# %%
len(df[df['minimum_nights']>200]['minimum_nights'])

# %%
len(df[df['minimum_nights']>100]['minimum_nights'])

# %% [markdown]
# Se considera que pueden existir alquileres que exijan ciertos meses de permanencia. Por tanto, no se considera outlier ninguno de los anteriores casos

# %% [markdown]
# **maximum**

# %% [markdown]
# Estudiamos nuevamente los estadísticos de la variable

# %%
# Estadisticos descriptivos
df['maximum_nights'].describe()
# Out:
# count     4077.000000
# mean       704.922492
# std       1671.309428
# min          3.000000
# 25%         60.000000
# 50%       1125.000000
# 75%       1125.000000
# max      99999.000000
# Name: maximum_nights, dtype: float64

# %% [markdown]
# Se puede observar que hay muchas observaciones concentradas en el valor 1125 (posiblemente sea un valor por defecto).
# Por tanto, imputamos este valor como cota máxima del número máximo de noches.

# %%
# Imputacion de cota maxima
df.loc[df['maximum_nights'] > 1125, 'maximum_nights'] = 1125

# %% [markdown]
# Procedemos a estudiar la distribución del número máximo de noches.

# %%
# Distribucion de maximum_nights
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.kdeplot(df['maximum_nights'], shade=True, color='blue', ax=axes[0])
sns.histplot(df['maximum_nights'], color='blue', bins = 30, ax=axes[1])

plt.show()

# %% [markdown]
# Nuevamente vemos como existen 2 picos. El primero que hace referencia a estancias de corta duración y otro que hace referencia estancias de larga duracion.

# %% [markdown]
# ## 1. 5 Transformaciones

# %% [markdown]
# Como habíamos comentado, las variables presentan asimetría, lo cual no es favorable para los modelos de regresión. Podemos estudiar esto mediante el coeficiente de asimetria de Fisher, que mida la centralidad de los datos. Si el coeficiente es 0, los datos están centrados entrorno a la media, si es postivo presentan asimetría por la derecha, y si es negativo asimetría por la izquierda.

# %%
# Simetria
df.skew(axis=0)
# Out:
# latitude                       -0.791346
# longitude                      -0.021084
# accommodates                    2.165358
# bathrooms                       3.202782
# bedrooms                        1.911314
# beds                            3.353368
# price                           5.427395
# security_deposit                4.451464
# cleaning_fee                    1.676987
# guests_included                 2.794345
# extra_people                    5.642732
# minimum_nights                  5.595829
# maximum_nights                 -0.296323
# number_of_reviews               3.092834
# review_scores_accuracy         -3.827218
# review_scores_cleanliness      -2.899111
# review_scores_checkin          -4.606664
# review_scores_communication    -5.201326
# review_scores_location         -2.807030
# Entire home/apt                -0.870772
# Private room                    0.909377
# Shared room                    11.532791
# dtype: float64

# %% [markdown]
# Así, aplicamos transformaciones logarísmicas a las variables continuas que no presentan simetría con sesgo positivo.

# %%
# Transfomacion
cols = ['accommodates', 'bathrooms', 'bedrooms', 'beds', 'price', 
        'security_deposit','cleaning_fee', 'guests_included', 
        'extra_people', 'minimum_nights','number_of_reviews']

for col in cols:
    df[col] = df[col].astype('float64').replace(0.0, 0.01)
    df[col] = np.log(df[col])

# %%
df.head()
# Out:
#         latitude   longitude  accommodates  bathrooms  bedrooms      beds  \
# id
# 10080  49.287716 -123.121103      1.791759   0.693147  0.693147  1.386294
# 13188  49.245770 -123.105158      1.386294   0.000000 -4.605170  0.693147
# 13358  49.282090 -123.125150      0.693147   0.000000  0.000000  0.000000
# 13490  49.255501 -123.066956      0.693147   0.000000  0.000000  0.000000
# 14267  49.249739 -123.081077      1.386294   0.000000  0.000000  0.693147
#
#           price  security_deposit  cleaning_fee  guests_included  ...  \
# id                                                                ...
# 10080  5.686975         -4.605170      5.273000         0.000000  ...
# 13188  4.779123         -4.605170      3.688879         0.000000  ...
# 13358  4.779123          5.703782      4.174387         0.000000  ...
# 13490  4.983607         -4.605170      3.688879         0.000000  ...
# 14267  4.941642         -4.605170      4.094345         0.693147  ...
#
#        maximum_nights  number_of_reviews  review_scores_accuracy  \
# id
# 10080            1124           2.772589                     9.0
# 13188            1125           5.105945                    10.0
# 13358              60           5.950643                    10.0
# 13490              90           4.406719                    10.0
# 14267              60           3.433987                    10.0
#
#        review_scores_cleanliness  review_scores_checkin  \
# id
# 10080                        9.0                   10.0
# 13188                       10.0                   10.0
# 13358                       10.0                   10.0
# 13490                       10.0                   10.0
# 14267                        9.0                   10.0
#
#        review_scores_communication  review_scores_location  Entire home/apt  \
# id
# 10080                          9.0                    10.0                1
# 13188                         10.0                    10.0                1
# 13358                         10.0                    10.0                1
# 13490                         10.0                     9.0                1
# 14267                          9.0                    10.0                1
#
#        Private room  Shared room
# id
# 10080             0            0
# 13188             0            0
# 13358             0            0
# 13490             0            0
# 14267             0            0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 1.6 Análisis de correlaciones

# %% [markdown]
# Para finalizar, estudiamos las correlaciones entre las variables. Así, podemos decidir qué variables usar para el modelo y estudiar posibles relaciones existentes entre ellas.

# %%
plt.figure(figsize=(20,10))
correlaciones= df.corr()
sns.heatmap(correlaciones,cmap="GnBu",annot=True) 
correlaciones
# Out:
#                              latitude  longitude  accommodates  bathrooms  \
# latitude                     1.000000  -0.092031     -0.021365  -0.008440
# longitude                   -0.092031   1.000000     -0.031268  -0.058819
# accommodates                -0.021365  -0.031268      1.000000   0.430513
# bathrooms                   -0.008440  -0.058819      0.430513   1.000000
# bedrooms                    -0.122958  -0.003896      0.399696   0.310023
# beds                        -0.068167  -0.007424      0.646593   0.322574
# price                        0.209753  -0.229923      0.643669   0.423870
# security_deposit             0.127378  -0.015656      0.214935   0.117334
# cleaning_fee                 0.112346  -0.038814      0.260998   0.148750
# guests_included             -0.024369  -0.011329      0.551579   0.245570
# extra_people                -0.060116   0.076823      0.165789   0.028480
# minimum_nights               0.224809  -0.093700     -0.119241   0.031713
# maximum_nights              -0.039920  -0.030925      0.024954   0.008215
# number_of_reviews            0.069897   0.062800      0.001669  -0.098829
# review_scores_accuracy       0.040801   0.022886     -0.025081  -0.055238
# review_scores_cleanliness    0.021820   0.040915      0.005517  -0.037522
# review_scores_checkin       -0.048050   0.025119     -0.001575  -0.030790
# review_scores_communication  0.043010   0.017057      0.013743  -0.019024
# review_scores_location       0.206416  -0.280743      0.058556   0.033179
# Entire home/apt              0.269445  -0.052578      0.522842   0.143113
# Private room                -0.279040   0.045474     -0.512202  -0.152074
# Shared room                  0.040784   0.039851     -0.076697   0.042245
#
#                              bedrooms      beds     price  security_deposit  \
# latitude                    -0.122958 -0.068167  0.209753          0.127378
# longitude                   -0.003896 -0.007424 -0.229923         -0.015656
# accommodates                 0.399696  0.646593  0.643669          0.214935
# bathrooms                    0.310023  0.322574  0.423870          0.117334
# bedrooms                     1.000000  0.340151  0.268068          0.053955
# beds                         0.340151  1.000000  0.406124          0.128840
# price                        0.268068  0.406124  1.000000          0.232700
# security_deposit             0.053955  0.128840  0.232700          1.000000
# cleaning_fee                 0.059407  0.162188  0.250404          0.297023
# guests_included              0.252717  0.396178  0.406743          0.214220
# extra_people                 0.116850  0.126551 -0.004690          0.115617
# minimum_nights              -0.076941 -0.062608 -0.019195          0.130243
# maximum_nights              -0.013844 -0.001393  0.016984         -0.009472
# number_of_reviews           -0.048525 -0.016689 -0.062194          0.070581
# review_scores_accuracy      -0.016290 -0.043988  0.035714          0.014121
# review_scores_cleanliness   -0.037437 -0.025815  0.074897          0.062777
# review_scores_checkin        0.022606  0.008780 -0.010054         -0.025663
# review_scores_communication  0.005496 -0.003404  0.055442          0.012684
# review_scores_location       0.025369  0.017749  0.176273          0.038949
# Entire home/apt              0.019037  0.306677  0.564207          0.256948
# Private room                -0.019175 -0.306391 -0.554099         -0.251930
# Shared room                  0.000010 -0.013270 -0.075448         -0.036567
#
#                              cleaning_fee  guests_included  ...  \
# latitude                         0.112346        -0.024369  ...
# longitude                       -0.038814        -0.011329  ...
# accommodates                     0.260998         0.551579  ...
# bathrooms                        0.148750         0.245570  ...
# bedrooms                         0.059407         0.252717  ...
# beds                             0.162188         0.396178  ...
# price                            0.250404         0.406743  ...
# security_deposit                 0.297023         0.214220  ...
# cleaning_fee                     1.000000         0.222281  ...
# guests_included                  0.222281         1.000000  ...
# extra_people                     0.148000         0.523726  ...
# minimum_nights                   0.012443        -0.072808  ...
# maximum_nights                   0.014814        -0.005516  ...
# number_of_reviews                0.019542         0.090956  ...
# review_scores_accuracy          -0.014533        -0.011043  ...
# review_scores_cleanliness        0.046709         0.030970  ...
# review_scores_checkin           -0.026803         0.012538  ...
# review_scores_communication      0.002314         0.014620  ...
# review_scores_location           0.035326         0.027765  ...
# Entire home/apt                  0.256770         0.326361  ...
# Private room                    -0.235767        -0.319933  ...
# Shared room                     -0.121698        -0.046732  ...
#
#                              maximum_nights  number_of_reviews  \
# latitude                          -0.039920           0.069897
# longitude                         -0.030925           0.062800
# accommodates                       0.024954           0.001669
# bathrooms                          0.008215          -0.098829
# bedrooms                          -0.013844          -0.048525
# beds                              -0.001393          -0.016689
# price                              0.016984          -0.062194
# security_deposit                  -0.009472           0.070581
# cleaning_fee                       0.014814           0.019542
# guests_included                   -0.005516           0.090956
# extra_people                      -0.004964           0.116505
# minimum_nights                     0.073244          -0.158752
# maximum_nights                     1.000000          -0.032972
# number_of_reviews                 -0.032972           1.000000
# review_scores_accuracy            -0.053068           0.159167
# review_scores_cleanliness         -0.047892           0.163465
# review_scores_checkin             -0.044276           0.126953
# review_scores_communication       -0.037093           0.150269
# review_scores_location            -0.017090           0.052757
# Entire home/apt                    0.009626           0.028909
# Private room                      -0.015486          -0.024359
# Shared room                        0.030840          -0.025338
#
#                              review_scores_accuracy  \
# latitude                                   0.040801
# longitude                                  0.022886
# accommodates                              -0.025081
# bathrooms                                 -0.055238
# bedrooms                                  -0.016290
# beds                                      -0.043988
# price                                      0.035714
# security_deposit                           0.014121
# cleaning_fee                              -0.014533
# guests_included                           -0.011043
# extra_people                              -0.047325
# minimum_nights                            -0.019242
# maximum_nights                            -0.053068
# number_of_reviews                          0.159167
# review_scores_accuracy                     1.000000
# review_scores_cleanliness                  0.560312
# review_scores_checkin                      0.533497
# review_scores_communication                0.599602
# review_scores_location                     0.376634
# Entire home/apt                            0.069077
# Private room                              -0.056525
# Shared room                               -0.069498
#
#                              review_scores_cleanliness  review_scores_checkin  \
# latitude                                      0.021820              -0.048050
# longitude                                     0.040915               0.025119
# accommodates                                  0.005517              -0.001575
# bathrooms                                    -0.037522              -0.030790
# bedrooms                                     -0.037437               0.022606
# beds                                         -0.025815               0.008780
# price                                         0.074897              -0.010054
# security_deposit                              0.062777              -0.025663
# cleaning_fee                                  0.046709              -0.026803
# guests_included                               0.030970               0.012538
# extra_people                                 -0.030890              -0.033674
# minimum_nights                               -0.058639              -0.013043
# maximum_nights                               -0.047892              -0.044276
# number_of_reviews                             0.163465               0.126953
# review_scores_accuracy                        0.560312               0.533497
# review_scores_cleanliness                     1.000000               0.405965
# review_scores_checkin                         0.405965               1.000000
# review_scores_communication                   0.447342               0.593330
# review_scores_location                        0.277985               0.272692
# Entire home/apt                               0.081188               0.030026
# Private room                                 -0.063159              -0.023931
# Shared room                                  -0.099132              -0.033615
#
#                              review_scores_communication  \
# latitude                                        0.043010
# longitude                                       0.017057
# accommodates                                    0.013743
# bathrooms                                      -0.019024
# bedrooms                                        0.005496
# beds                                           -0.003404
# price                                           0.055442
# security_deposit                                0.012684
# cleaning_fee                                    0.002314
# guests_included                                 0.014620
# extra_people                                   -0.037209
# minimum_nights                                 -0.041508
# maximum_nights                                 -0.037093
# number_of_reviews                               0.150269
# review_scores_accuracy                          0.599602
# review_scores_cleanliness                       0.447342
# review_scores_checkin                           0.593330
# review_scores_communication                     1.000000
# review_scores_location                          0.366837
# Entire home/apt                                 0.086722
# Private room                                   -0.076617
# Shared room                                    -0.057142
#
#                              review_scores_location  Entire home/apt  \
# latitude                                   0.206416         0.269445
# longitude                                 -0.280743        -0.052578
# accommodates                               0.058556         0.522842
# bathrooms                                  0.033179         0.143113
# bedrooms                                   0.025369         0.019037
# beds                                       0.017749         0.306677
# price                                      0.176273         0.564207
# security_deposit                           0.038949         0.256948
# cleaning_fee                               0.035326         0.256770
# guests_included                            0.027765         0.326361
# extra_people                              -0.055074        -0.057073
# minimum_nights                             0.065937         0.173213
# maximum_nights                            -0.017090         0.009626
# number_of_reviews                          0.052757         0.028909
# review_scores_accuracy                     0.376634         0.069077
# review_scores_cleanliness                  0.277985         0.081188
# review_scores_checkin                      0.272692         0.030026
# review_scores_communication                0.366837         0.086722
# review_scores_location                     1.000000         0.136324
# Entire home/apt                            0.136324         1.000000
# Private room                              -0.132816        -0.982525
# Shared room                               -0.023903        -0.131371
#
#                              Private room  Shared room
# latitude                        -0.279040     0.040784
# longitude                        0.045474     0.039851
# accommodates                    -0.512202    -0.076697
# bathrooms                       -0.152074     0.042245
# bedrooms                        -0.019175     0.000010
# beds                            -0.306391    -0.013270
# price                           -0.554099    -0.075448
# security_deposit                -0.251930    -0.036567
# cleaning_fee                    -0.235767    -0.121698
# guests_included                 -0.319933    -0.046732
# extra_people                     0.048355     0.048618
# minimum_nights                  -0.184764     0.054887
# maximum_nights                  -0.015486     0.030840
# number_of_reviews               -0.024359    -0.025338
# review_scores_accuracy          -0.056525    -0.069498
# review_scores_cleanliness       -0.063159    -0.099132
# review_scores_checkin           -0.023931    -0.033615
# review_scores_communication     -0.076617    -0.057142
# review_scores_location          -0.132816    -0.023903
# Entire home/apt                 -0.982525    -0.131371
# Private room                     1.000000    -0.055441
# Shared room                     -0.055441     1.000000
#
# [22 rows x 22 columns]

# %% [markdown]
# Así, seleccionamos las siguientes variables para el modelo:
#
# Las variables de modelización:
# * _latitude_
# * _longitude_
# * _accommodates_
# * _bedrooms_
# * _security_deposit_
# * _cleaning_fee_
# * _review_scores_accuracy_
# * _Entire home/apt_
# * _Private_room_
#
# Y la varibale de etiqueta:
# * _logPrice_

# %% [markdown]
# Obtenemos el siguiente dataframe

# %% [markdown]
# # 2. División de los datos

# %%
# Paquetes y liberias
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# En primer lugar, creamos la matriz de observaciones y el vector etiqueta con los que trabajaremos para ajustar el modelo de regresión lineal.

# %%
# Vector etiqueta
y = df['price']

# Matriz de observaciones
X = df[['latitude', 'longitude', 'accommodates', 'bedrooms', 
        'security_deposit', 'cleaning_fee', 'review_scores_accuracy',
        'Entire home/apt', 'Private room']]

# %%
# Estandarizamos los datos
objeto = StandardScaler()
X_ss = pd.DataFrame(objeto.fit_transform(X.iloc[:,0:7]), columns=list(X.iloc[:,0:7].columns))
# Concatenamos los datos
X = pd.concat([X_ss, X.loc[:,'Entire home/apt':'Private room'].reset_index()], axis=1)
X.head(5)
# Out:
#    latitude  longitude  accommodates  bedrooms  security_deposit  \
# 0  1.269452  -0.274052      1.261547  0.534031         -1.366687
# 1 -0.797168   0.127711      0.529885 -3.547172         -1.366687
# 2  0.992269  -0.376029     -0.720901  0.000112          0.688669
# 3 -0.317746   1.090327     -0.720901  0.000112         -1.366687
# 4 -0.601618   0.734505      0.529885  0.000112         -1.366687
#
#    cleaning_fee  review_scores_accuracy     id  Entire home/apt  Private room
# 0      0.735544               -1.059082  10080                1             0
# 1      0.125794                0.452251  13188                1             0
# 2      0.312673                0.452251  13358                1             0
# 3      0.125794                0.452251  13490                1             0
# 4      0.281863                0.452251  14267                1             0

# %% [markdown]
# Separamos los datos en train y test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Librerias
import os

# Carpeta con datos
if not os.path.exists('Datos'):
    os.makedirs('Datos')
    
# Guardamos los datos
X_train.to_csv('Datos/X_train.csv', index=False)
X_test.to_csv('Datos/X_test.csv', index=False)
y_train.to_csv('Datos/y_train.csv', index=False)
y_test.to_csv('Datos/y_test.csv', index=False)
